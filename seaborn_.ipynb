# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
titanic = sns.load_dataset('titanic')
planets = sns.load_dataset("planets")

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.scatterplot(x= 'age' ,y = 'fare' ,data = titanic )
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(data = tips ,  x='total_bill' ,  y = 'tip'  ,  hue = 'day'  ,style = 'sex', size = 'size' , palette = 'YlGnBu')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
df = sns.load_dataset('penguins')

# %%
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(data = tips , kind = 'line'  , y='total_bill'  , x = 'tip')

# %%
iris = sns.load_dataset('iris')

# %%
iris.sample(5)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 120           6.9          3.2           5.7          2.3   virginica
# 119           6.0          2.2           5.0          1.5   virginica
# 60            5.0          2.0           3.5          1.0  versicolor
# 6             4.6          3.4           1.4          0.3      setosa
# 34            4.9          3.1           1.5          0.2      setosa

# %%
set(iris['species'])
# Out:
# {'setosa', 'versicolor', 'virginica'}

# %%
sns.relplot( data = iris ,kind = 'line' , x = 'species' , y= 'petal_width' ,hue =   )

# %%
temp_df = iris[iris['species'].isin(['setosa', 'versicolor', 'virginica'])]

# %%
sns.lineplot(data = temp_df   ,  y = 'petal_length' ,x= 'petal_width' , hue = 'species')
# Out:
# <Axes: xlabel='petal_width', ylabel='petal_length'>

# %%
#sns.barplot(data = iris , x = 'species', y = 'sepal_width' )

sns.scatterplot(data = iris , x = 'species', y = 'sepal_width', hue = 'sepal_length')
# Out:
# <Axes: xlabel='species', ylabel='sepal_width'>

# %%
sns.relplot(data = iris, kind = 'scatter',y = 'sepal_width', x = 'sepal_length' ,col = 'species')

# %% [markdown]
# # CAMPUSX

# %%
tip = sns.load_dataset('tips')

# %%
tip.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(data = tip , kind = 'scatter' , y = 'total_bill' , x = 'tip' , col = 'sex' , row = 'smoker')

# %%
planets = sns.load_dataset('planets')
planets.sample(6)
# Out:
#                method  number  orbital_period  mass  distance  year
# 866           Transit       2       22.951000   NaN       NaN  2013
# 1021          Transit       1        2.484193   NaN    260.00  2013
# 1015          Transit       1        1.573292   NaN    350.00  2012
# 890           Transit       2        2.426290   NaN       NaN  2014
# 17    Radial Velocity       5       14.651000   0.8     12.53  1996
# 490   Radial Velocity       1        2.875891   NaN     78.86  2005

# %%
sns.relplot(data = planets ,  kind = 'scatter'  ,  x = 'mass'  , y = 'distance'  ,col = 'year' , col_wrap = 3 )

# %%
tips.tail(3)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
sns.histplot(data = tip , x =  'total_bill' , kde =True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.displot(data = tip , x =  'total_bill' , bins = 243 )

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.histplot(data = titanic , x = 'age'  , hue= 'sex' )
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.displot(kind = 'hist' , data = titanic , x = 'age'  , hue= 'sex' ,element = 'step', col = 'survived' )

# %%
sns.displot(kind = 'kde' , data = titanic , x = 'age' , hue = 'sex' , fill= True)
sns.rugplot( data = titanic , x = 'age' )
# Out:
# <Axes: xlabel='age', ylabel='Density'>
